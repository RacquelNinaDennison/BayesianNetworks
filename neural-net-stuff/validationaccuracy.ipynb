# %% [markdown]
# In this notebook, experiments are run on the randomisation of hyperparameters

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
import random
import copy

# %%
class RandomOptimiser(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3):
        super(RandomOptimiser, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, 3)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
def train_model(model, train_loader, valid_features, valid_labels, criterion, optimizer, epochs):
    train_losses = []
    train_accuracies = []
    valid_losses = []
    valid_accuracies = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for batch_features, batch_labels in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_features)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Calculate training metrics
        model.eval()
        with torch.no_grad():
            train_outputs = model(train_loader.dataset.tensors[0])
            train_loss = criterion(train_outputs, train_loader.dataset.tensors[1])
            train_predicted = torch.argmax(train_outputs, dim=1)
            train_accuracy = (train_predicted == train_loader.dataset.tensors[1]).float().mean()
            valid_outputs = model(valid_features)
            valid_loss = criterion(valid_outputs, valid_labels)
            valid_predicted = torch.argmax(valid_outputs, dim=1)
            valid_accuracy = (valid_predicted == valid_labels).float().mean()

        train_losses.append(running_loss / len(train_loader))
        train_accuracies.append(train_accuracy.item())
        valid_losses.append(valid_loss.item())
        valid_accuracies.append(valid_accuracy.item())

        if (epoch + 1) % 50 == 0:
            print(f'Epoch [{epoch + 1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Valid Loss: {valid_losses[-1]:.4f}')
            print(f'Train Accuracy: {train_accuracies[-1]:.4f}, Valid Accuracy: {valid_accuracies[-1]:.4f}')

    return train_losses, train_accuracies, valid_losses, valid_accuracies

# %%
def random_search(train_features, train_labels, valid_features, valid_labels, n_trials=10):
    param_space = {
        'learning_rate': [0.0001, 0.001, 0.01],
        'batch_size': [16, 32, 64],
        'epochs': [100, 200, 300],
        'hidden_size1': [32, 64, 128],
        'hidden_size2': [16, 32, 64],
        'hidden_size3': [8, 16, 32],
    }

    best_valid_accuracy = 0
    lowest_valid_loss = float('inf')
    best_model_accuracy = None
    best_model_loss = None
    best_params_accuracy = None
    best_params_loss = None

    input_size = train_features.shape[1]

    for trial in range(n_trials):
        current_params = {
            'learning_rate': random.choice(param_space['learning_rate']),
            'batch_size': random.choice(param_space['batch_size']),
            'epochs': random.choice(param_space['epochs']),
            'hidden_size1': random.choice(param_space['hidden_size1']),
            'hidden_size2': random.choice(param_space['hidden_size2']),
            'hidden_size3': random.choice(param_space['hidden_size3']),
        }

        print(f"\nTrial {trial + 1}/{n_trials}")
        print("Current parameters:", current_params)

        model = RandomOptimiser(input_size, current_params['hidden_size1'], current_params['hidden_size2'], current_params['hidden_size3'])
        train_dataset = data.TensorDataset(train_features, train_labels)
        train_loader = data.DataLoader(train_dataset, batch_size=current_params['batch_size'], shuffle=True)

        # Training setup
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=current_params['learning_rate'])

        # Train the model
        train_losses, train_accuracies, valid_losses, valid_accuracies = train_model(
            model, train_loader, valid_features, valid_labels, criterion, optimizer, current_params['epochs']
        )

        final_valid_accuracy = valid_accuracies[-1]
        final_valid_loss = valid_losses[-1]

        # Track the best validation accuracy
        if final_valid_accuracy > best_valid_accuracy:
            best_valid_accuracy = final_valid_accuracy
            best_model_accuracy = copy.deepcopy(model)
            best_params_accuracy = current_params
            print(f"New best model by Validation Accuracy! Accuracy: {best_valid_accuracy:.4f}")

        # Track the lowest validation loss
        if final_valid_loss < lowest_valid_loss:
            lowest_valid_loss = final_valid_loss
            best_model_loss = copy.deepcopy(model)
            best_params_loss = current_params
            print(f"New best model by Validation Loss! Loss: {lowest_valid_loss:.4f}")

    return best_model_accuracy, best_params_accuracy, best_valid_accuracy, best_model_loss, best_params_loss, lowest_valid_loss

# %%
def process_data(data):
    features = []
    labels = []
    for line in data:
        if line.strip():
            split_line = list(map(float, line.split(',')))
            features.append(split_line[:-1])
            labels.append(int(split_line[-1]))
    return torch.tensor(features, dtype=torch.float32), torch.tensor(labels, dtype=torch.long)

# %%
if __name__ == "__main__":
    TestingData = open('TestingEncoded.csv', 'r').read().split("\n")[1:]
    TrainingData = open('TrainingEncoded.csv', 'r').read().split("\n")[1:]
    ValidationData = open('ValidationEncoded.csv', 'r').read().split("\n")[1:]

    # Process data
    train_features, train_labels = process_data(TrainingData)
    valid_features, valid_labels = process_data(ValidationData)
    test_features, test_labels = process_data(TestingData)

    # Number of runs
    num_runs = 5

    best_model_accuracy_runs = None
    best_model_loss_runs = None
    best_params_accuracy_runs = None
    best_params_loss_runs = None
    best_valid_accuracy_runs = 0
    best_valid_loss_runs = float('inf')

    for run in range(num_runs):
        print(f"\nRun {run + 1}/{num_runs}")
        
        # Perform random search
        best_model_accuracy, best_params_accuracy, best_valid_accuracy, best_model_loss, best_params_loss, lowest_valid_loss = random_search(
            train_features, train_labels, valid_features, valid_labels, n_trials=10
        )

        # Compare across runs for best accuracy
        if best_valid_accuracy > best_valid_accuracy_runs:
            best_valid_accuracy_runs = best_valid_accuracy
            best_model_accuracy_runs = best_model_accuracy
            best_params_accuracy_runs = best_params_accuracy
        
        # Compare across runs for lowest validation loss
        if lowest_valid_loss < best_valid_loss_runs:
            best_valid_loss_runs = lowest_valid_loss
            best_model_loss_runs = best_model_loss
            best_params_loss_runs = best_params_loss

    # Print the best hyperparameters and results
    print("\nBest Validation Accuracy Across Runs:")
    print(f"Validation Accuracy: {best_valid_accuracy_runs:.4f}")
    print(f"Best Hyperparameters (Accuracy): {best_params_accuracy_runs}")

    print("\nLowest Validation Loss Across Runs:")
    print(f"Validation Loss: {best_valid_loss_runs:.4f}")
    print(f"Best Hyperparameters (Loss): {best_params_loss_runs}")

    # Save the models
    torch.save(best_model_accuracy_runs.state_dict(), 'best_model_accuracy.pth')
    torch.save(best_model_loss_runs.state_dict(), 'best_model_loss.pth')
# Out:
# Run 1/5
#
# Trial 1/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 1.0507, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0504, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Accuracy! Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0487
#
# Trial 2/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 0.4592, Valid Loss: 0.5973
# Train Accuracy: 0.8688, Valid Accuracy: 0.7637
# Epoch [100/200], Train Loss: 0.4335, Valid Loss: 0.3953
# Train Accuracy: 0.8950, Valid Accuracy: 0.8868
# Epoch [150/200], Train Loss: 0.4093, Valid Loss: 0.4202
# Train Accuracy: 0.8885, Valid Accuracy: 0.8733
# Epoch [200/200], Train Loss: 0.4120, Valid Loss: 0.3856
# Train Accuracy: 0.8955, Valid Accuracy: 0.8916
# New best model by Validation Accuracy! Accuracy: 0.8916
# New best model by Validation Loss! Loss: 0.3856
#
# Trial 3/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 0.7771, Valid Loss: 1.0624
# Train Accuracy: 0.6906, Valid Accuracy: 0.4196
# Epoch [100/100], Train Loss: 0.6984, Valid Loss: 1.4381
# Train Accuracy: 0.7295, Valid Accuracy: 0.4344
#
# Trial 4/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 64, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 1.0505, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0505, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0505, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 5/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.7175, Valid Loss: 0.9270
# Train Accuracy: 0.6802, Valid Accuracy: 0.5659
# Epoch [100/100], Train Loss: 0.6843, Valid Loss: 1.1334
# Train Accuracy: 0.7248, Valid Accuracy: 0.4992
#
# Trial 6/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 1.0511, Valid Loss: 1.0511
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0514, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 7/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 0.7294, Valid Loss: 0.7885
# Train Accuracy: 0.6763, Valid Accuracy: 0.6164
# Epoch [100/200], Train Loss: 0.6788, Valid Loss: 0.8849
# Train Accuracy: 0.7609, Valid Accuracy: 0.5673
# Epoch [150/200], Train Loss: 0.6589, Valid Loss: 0.6921
# Train Accuracy: 0.7772, Valid Accuracy: 0.7132
# Epoch [200/200], Train Loss: 0.6416, Valid Loss: 0.6465
# Train Accuracy: 0.7539, Valid Accuracy: 0.7621
#
# Trial 8/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.6373, Valid Loss: 1.6354
# Train Accuracy: 0.6039, Valid Accuracy: 0.3420
# Epoch [100/100], Train Loss: 0.4608, Valid Loss: 0.4535
# Train Accuracy: 0.8550, Valid Accuracy: 0.8393
#
# Trial 9/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 32, 'epochs': 300, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 8}
# Epoch [50/300], Train Loss: 1.0512, Valid Loss: 1.0492
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/300], Train Loss: 1.0511, Valid Loss: 1.0491
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/300], Train Loss: 1.0511, Valid Loss: 1.0491
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/300], Train Loss: 1.0510, Valid Loss: 1.0503
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [250/300], Train Loss: 1.0511, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [300/300], Train Loss: 1.0512, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 10/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/200], Train Loss: 1.0513, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0516, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0512, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0511, Valid Loss: 1.0519
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Run 2/5
#
# Trial 1/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.8378, Valid Loss: 1.0900
# Train Accuracy: 0.6132, Valid Accuracy: 0.5179
# Epoch [100/100], Train Loss: 0.7890, Valid Loss: 0.8703
# Train Accuracy: 0.7507, Valid Accuracy: 0.5757
# New best model by Validation Accuracy! Accuracy: 0.5757
# New best model by Validation Loss! Loss: 0.8703
#
# Trial 2/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 64, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 16, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 1.0510, Valid Loss: 1.0497
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0507, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0509, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0513, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 3/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 0.7114, Valid Loss: 1.0575
# Train Accuracy: 0.7301, Valid Accuracy: 0.5094
# Epoch [100/200], Train Loss: 0.6870, Valid Loss: 1.2909
# Train Accuracy: 0.7160, Valid Accuracy: 0.4124
# Epoch [150/200], Train Loss: 0.6442, Valid Loss: 0.9271
# Train Accuracy: 0.7540, Valid Accuracy: 0.5604
# Epoch [200/200], Train Loss: 0.6195, Valid Loss: 0.6605
# Train Accuracy: 0.7897, Valid Accuracy: 0.7206
# New best model by Validation Accuracy! Accuracy: 0.7206
# New best model by Validation Loss! Loss: 0.6605
#
# Trial 4/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 300, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 32}
# Epoch [50/300], Train Loss: 0.7307, Valid Loss: 1.0884
# Train Accuracy: 0.7191, Valid Accuracy: 0.4274
# Epoch [100/300], Train Loss: 0.6922, Valid Loss: 0.9437
# Train Accuracy: 0.7378, Valid Accuracy: 0.6168
# Epoch [150/300], Train Loss: 0.6690, Valid Loss: 0.8271
# Train Accuracy: 0.7534, Valid Accuracy: 0.6600
# Epoch [200/300], Train Loss: 0.6235, Valid Loss: 0.6420
# Train Accuracy: 0.7559, Valid Accuracy: 0.7660
# Epoch [250/300], Train Loss: 0.5803, Valid Loss: 0.9160
# Train Accuracy: 0.8096, Valid Accuracy: 0.6160
# Epoch [300/300], Train Loss: 0.5219, Valid Loss: 0.6804
# Train Accuracy: 0.8458, Valid Accuracy: 0.7165
#
# Trial 5/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 32}
# Epoch [50/100], Train Loss: 0.8188, Valid Loss: 0.8016
# Train Accuracy: 0.6198, Valid Accuracy: 0.5857
# Epoch [100/100], Train Loss: 0.7348, Valid Loss: 1.1900
# Train Accuracy: 0.6366, Valid Accuracy: 0.5358
#
# Trial 6/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 1.0512, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0515, Valid Loss: 1.0496
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 7/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 0.9140, Valid Loss: 1.4293
# Train Accuracy: 0.4849, Valid Accuracy: 0.4867
# Epoch [100/100], Train Loss: 0.7373, Valid Loss: 0.9558
# Train Accuracy: 0.7215, Valid Accuracy: 0.5504
#
# Trial 8/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.7429, Valid Loss: 0.7432
# Train Accuracy: 0.6714, Valid Accuracy: 0.6648
# Epoch [100/100], Train Loss: 0.7123, Valid Loss: 1.0799
# Train Accuracy: 0.7410, Valid Accuracy: 0.4874
#
# Trial 9/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 32}
# Epoch [50/100], Train Loss: 0.6523, Valid Loss: 0.6140
# Train Accuracy: 0.7529, Valid Accuracy: 0.7832
# Epoch [100/100], Train Loss: 0.5294, Valid Loss: 0.5599
# Train Accuracy: 0.8352, Valid Accuracy: 0.7737
# New best model by Validation Accuracy! Accuracy: 0.7737
# New best model by Validation Loss! Loss: 0.5599
#
# Trial 10/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 300, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/300], Train Loss: 0.6823, Valid Loss: 0.9139
# Train Accuracy: 0.7587, Valid Accuracy: 0.6176
# Epoch [100/300], Train Loss: 0.6291, Valid Loss: 1.0871
# Train Accuracy: 0.7645, Valid Accuracy: 0.6042
# Epoch [150/300], Train Loss: 0.5582, Valid Loss: 0.6787
# Train Accuracy: 0.8217, Valid Accuracy: 0.7319
# Epoch [200/300], Train Loss: 0.5128, Valid Loss: 0.8743
# Train Accuracy: 0.8303, Valid Accuracy: 0.6499
# Epoch [250/300], Train Loss: 0.4965, Valid Loss: 0.6712
# Train Accuracy: 0.8459, Valid Accuracy: 0.7503
# Epoch [300/300], Train Loss: 0.4833, Valid Loss: 0.5691
# Train Accuracy: 0.8250, Valid Accuracy: 0.7904
# New best model by Validation Accuracy! Accuracy: 0.7904
#
# Run 3/5
#
# Trial 1/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 1.0510, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0508, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Accuracy! Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0489
#
# Trial 2/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 300, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/300], Train Loss: 1.0515, Valid Loss: 1.0497
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/300], Train Loss: 1.0516, Valid Loss: 1.0491
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/300], Train Loss: 1.0511, Valid Loss: 1.0505
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/300], Train Loss: 1.0513, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [250/300], Train Loss: 1.0514, Valid Loss: 1.0514
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [300/300], Train Loss: 1.0513, Valid Loss: 1.0499
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 3/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 1.0510, Valid Loss: 1.0503
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0513, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0511, Valid Loss: 1.0491
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0509, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 4/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 0.6476, Valid Loss: 0.7049
# Train Accuracy: 0.7653, Valid Accuracy: 0.6761
# Epoch [100/100], Train Loss: 0.4591, Valid Loss: 0.4903
# Train Accuracy: 0.8381, Valid Accuracy: 0.8357
# New best model by Validation Accuracy! Accuracy: 0.8357
# New best model by Validation Loss! Loss: 0.4903
#
# Trial 5/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 1.0510, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0511, Valid Loss: 1.0493
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 6/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 0.8190, Valid Loss: 1.1745
# Train Accuracy: 0.6582, Valid Accuracy: 0.4010
# Epoch [100/200], Train Loss: 0.7222, Valid Loss: 1.0163
# Train Accuracy: 0.7178, Valid Accuracy: 0.4544
# Epoch [150/200], Train Loss: 0.7062, Valid Loss: 0.8537
# Train Accuracy: 0.7094, Valid Accuracy: 0.6472
# Epoch [200/200], Train Loss: 0.6795, Valid Loss: 1.3450
# Train Accuracy: 0.7099, Valid Accuracy: 0.4160
#
# Trial 7/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 32, 'hidden_size2': 32, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.8202, Valid Loss: 2.1695
# Train Accuracy: 0.5502, Valid Accuracy: 0.2660
# Epoch [100/100], Train Loss: 0.7586, Valid Loss: 0.9237
# Train Accuracy: 0.7396, Valid Accuracy: 0.5302
#
# Trial 8/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 1.0514, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0510, Valid Loss: 1.0525
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0518, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0516, Valid Loss: 1.0493
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 9/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 32, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.5448, Valid Loss: 0.5952
# Train Accuracy: 0.7274, Valid Accuracy: 0.7846
# Epoch [100/100], Train Loss: 0.4400, Valid Loss: 0.6467
# Train Accuracy: 0.8365, Valid Accuracy: 0.7393
#
# Trial 10/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 32, 'hidden_size3': 32}
# Epoch [50/100], Train Loss: 1.0514, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0512, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Run 4/5
#
# Trial 1/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 32, 'epochs': 300, 'hidden_size1': 64, 'hidden_size2': 32, 'hidden_size3': 16}
# Epoch [50/300], Train Loss: 1.0510, Valid Loss: 1.0497
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/300], Train Loss: 1.0510, Valid Loss: 1.0495
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/300], Train Loss: 1.0512, Valid Loss: 1.0493
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/300], Train Loss: 1.0513, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [250/300], Train Loss: 1.0510, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [300/300], Train Loss: 1.0511, Valid Loss: 1.0496
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Accuracy! Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0496
#
# Trial 2/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 64, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 1.0509, Valid Loss: 1.0492
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0510, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0508, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0513, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0487
#
# Trial 3/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 1.0513, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0514, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 4/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 1.0506, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0505, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0507, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0507, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0486
#
# Trial 5/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/200], Train Loss: 0.4949, Valid Loss: 0.4899
# Train Accuracy: 0.8693, Valid Accuracy: 0.8133
# Epoch [100/200], Train Loss: 0.4619, Valid Loss: 0.4983
# Train Accuracy: 0.8298, Valid Accuracy: 0.8253
# Epoch [150/200], Train Loss: 0.4477, Valid Loss: 0.4211
# Train Accuracy: 0.8754, Valid Accuracy: 0.8737
# Epoch [200/200], Train Loss: 0.4385, Valid Loss: 0.4596
# Train Accuracy: 0.8525, Valid Accuracy: 0.8461
# New best model by Validation Accuracy! Accuracy: 0.8461
# New best model by Validation Loss! Loss: 0.4596
#
# Trial 6/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.7477, Valid Loss: 0.8029
# Train Accuracy: 0.7402, Valid Accuracy: 0.6360
# Epoch [100/100], Train Loss: 0.5832, Valid Loss: 1.2511
# Train Accuracy: 0.7900, Valid Accuracy: 0.5143
#
# Trial 7/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 300, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 32}
# Epoch [50/300], Train Loss: 0.7240, Valid Loss: 0.8287
# Train Accuracy: 0.6680, Valid Accuracy: 0.6135
# Epoch [100/300], Train Loss: 0.5938, Valid Loss: 1.2787
# Train Accuracy: 0.7807, Valid Accuracy: 0.5188
# Epoch [150/300], Train Loss: 0.5164, Valid Loss: 0.4907
# Train Accuracy: 0.8304, Valid Accuracy: 0.8363
# Epoch [200/300], Train Loss: 0.4942, Valid Loss: 0.7996
# Train Accuracy: 0.8514, Valid Accuracy: 0.6974
# Epoch [250/300], Train Loss: 0.4711, Valid Loss: 1.3236
# Train Accuracy: 0.7767, Valid Accuracy: 0.5237
# Epoch [300/300], Train Loss: 0.4572, Valid Loss: 0.8021
# Train Accuracy: 0.8675, Valid Accuracy: 0.7057
#
# Trial 8/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/200], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0506, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0506, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 9/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 1.0518, Valid Loss: 1.0492
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0515, Valid Loss: 1.0493
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0509, Valid Loss: 1.0538
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0515, Valid Loss: 1.0493
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 10/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0507, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Run 5/5
#
# Trial 1/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 1.0518, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0514, Valid Loss: 1.0498
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0511, Valid Loss: 1.0504
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0516, Valid Loss: 1.0501
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# New best model by Validation Accuracy! Accuracy: 0.4866
# New best model by Validation Loss! Loss: 1.0501
#
# Trial 2/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 0.6222, Valid Loss: 0.6145
# Train Accuracy: 0.7631, Valid Accuracy: 0.7607
# Epoch [100/200], Train Loss: 0.4497, Valid Loss: 0.7303
# Train Accuracy: 0.8376, Valid Accuracy: 0.7096
# Epoch [150/200], Train Loss: 0.4371, Valid Loss: 0.4069
# Train Accuracy: 0.9007, Valid Accuracy: 0.8821
# Epoch [200/200], Train Loss: 0.4195, Valid Loss: 0.4184
# Train Accuracy: 0.8986, Valid Accuracy: 0.8653
# New best model by Validation Accuracy! Accuracy: 0.8653
# New best model by Validation Loss! Loss: 0.4184
#
# Trial 3/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 300, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/300], Train Loss: 0.7245, Valid Loss: 1.3919
# Train Accuracy: 0.7243, Valid Accuracy: 0.4515
# Epoch [100/300], Train Loss: 0.6394, Valid Loss: 1.8719
# Train Accuracy: 0.6577, Valid Accuracy: 0.3188
# Epoch [150/300], Train Loss: 0.5351, Valid Loss: 0.5606
# Train Accuracy: 0.8129, Valid Accuracy: 0.7929
# Epoch [200/300], Train Loss: 0.5000, Valid Loss: 0.6086
# Train Accuracy: 0.8309, Valid Accuracy: 0.7663
# Epoch [250/300], Train Loss: 0.4924, Valid Loss: 0.4983
# Train Accuracy: 0.8399, Valid Accuracy: 0.8259
# Epoch [300/300], Train Loss: 0.4706, Valid Loss: 0.5798
# Train Accuracy: 0.8637, Valid Accuracy: 0.7998
#
# Trial 4/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 128, 'hidden_size2': 64, 'hidden_size3': 32}
# Epoch [50/200], Train Loss: 0.4825, Valid Loss: 0.9999
# Train Accuracy: 0.8034, Valid Accuracy: 0.6298
# Epoch [100/200], Train Loss: 0.4346, Valid Loss: 0.4762
# Train Accuracy: 0.8785, Valid Accuracy: 0.8435
# Epoch [150/200], Train Loss: 0.4243, Valid Loss: 0.4697
# Train Accuracy: 0.8733, Valid Accuracy: 0.8421
# Epoch [200/200], Train Loss: 0.4287, Valid Loss: 0.5127
# Train Accuracy: 0.8591, Valid Accuracy: 0.8065
#
# Trial 5/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 32, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 64, 'hidden_size3': 8}
# Epoch [50/200], Train Loss: 1.0505, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0505, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 6/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 64, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/200], Train Loss: 1.0510, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0513, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0509, Valid Loss: 1.0488
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0512, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 7/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 100, 'hidden_size1': 64, 'hidden_size2': 64, 'hidden_size3': 16}
# Epoch [50/100], Train Loss: 0.6721, Valid Loss: 0.9478
# Train Accuracy: 0.7770, Valid Accuracy: 0.6366
# Epoch [100/100], Train Loss: 0.6237, Valid Loss: 1.1004
# Train Accuracy: 0.7779, Valid Accuracy: 0.5762
#
# Trial 8/10
# Current parameters: {'learning_rate': 0.001, 'batch_size': 64, 'epochs': 200, 'hidden_size1': 64, 'hidden_size2': 16, 'hidden_size3': 16}
# Epoch [50/200], Train Loss: 1.0510, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/200], Train Loss: 1.0505, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/200], Train Loss: 1.0507, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/200], Train Loss: 1.0505, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 9/10
# Current parameters: {'learning_rate': 0.01, 'batch_size': 64, 'epochs': 300, 'hidden_size1': 32, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/300], Train Loss: 1.0508, Valid Loss: 1.0490
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/300], Train Loss: 1.0509, Valid Loss: 1.0494
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [150/300], Train Loss: 1.0510, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [200/300], Train Loss: 1.0509, Valid Loss: 1.0489
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [250/300], Train Loss: 1.0512, Valid Loss: 1.0486
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [300/300], Train Loss: 1.0506, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Trial 10/10
# Current parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100, 'hidden_size1': 128, 'hidden_size2': 32, 'hidden_size3': 8}
# Epoch [50/100], Train Loss: 1.0503, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
# Epoch [100/100], Train Loss: 1.0504, Valid Loss: 1.0487
# Train Accuracy: 0.4837, Valid Accuracy: 0.4866
#
# Best Validation Accuracy Across Runs:
# Validation Accuracy: 0.8916
# Best Hyperparameters (Accuracy): {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 32}
#
# Lowest Validation Loss Across Runs:
# Validation Loss: 0.3856
# Best Hyperparameters (Loss): {'learning_rate': 0.001, 'batch_size': 16, 'epochs': 200, 'hidden_size1': 32, 'hidden_size2': 64, 'hidden_size3': 32}
